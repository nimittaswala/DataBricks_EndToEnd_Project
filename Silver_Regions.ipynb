# %%
df = spark.read.table("databricks_cata.bronze.regions")

# %%
df.display()

# %%
df = df.drop("_rescued_data")

# %%
df.write.format("delta").mode("overwrite").save("abfss://silver@databricksetenimit.dfs.core.windows.net/regions")
